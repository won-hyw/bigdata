# %% [markdown]
# ![R데이터구조1.png](data:image/png;base64,...)

# %% [markdown]
# # 1. 벡터(Vector)
#
# - 동일한 유형의 데이터로 구성된 1차원 데이터 구조
# - R에서 단일값(스킬라)은 원소가 하나인 벡터로 인식

# %%
# 벡터 표현법
V1 <- c(1, 2, 3)
V2 <- c("Hello", "World!")

print(V1)
print(V2)
# Out:
# [1] 1 2 3
# [1] "Hello"  "World!"

# %%
V <- c(1, "Hello") # 1은 동일한 유형으로 맞춰지기 위해 문자열로 변경이 일어난다
print(V)
# Out:
# [1] "1"     "Hello"

# %% [markdown]
# #2. 요인(Factor)
#
# - 범주형 데이터
#   - 데이터가 사전에 정해진 특정 유형으로 분류되는 경우
#   - 사전에 정해진 특정 유형을 레벨이라고 함
#   - 명목형과 순서형으로 구분
#     - 명목형 : 값들 간 크기 비교가 불가한 경우(성별)
#     - 순서형 : 대, 중, 소와 같이 값에 순서를 둘 수 있는 경우

# %% [markdown]
# ![범주형_수치형.png](data:image/png;base64,...)

# %%
# 요인 표현법
F1 <- factor(c("좋다", "보통이다", "싫다"), level = c("좋다", "보통이다", "싫다"), order = T)
print(F1)
# Out:
# [1] 좋다     보통이다 싫다
# Levels: 좋다 < 보통이다 < 싫다

# %% [markdown]
# # 3. 행렬(Matrix)
#
# - 동일한 유형의 2차원 데이터 구조(행과 열)
# - R에서는 차원을 가진 벡터로 인식

# %%
# 행렬 표현법
M1 <- matrix(1:9, nrow = 3)
print(M1)
# Out:
#      [,1] [,2] [,3]
# [1,]    1    4    7
# [2,]    2    5    8
# [3,]    3    6    9

# %% [markdown]
# # 4. 배열(Array)
#
# - 2차원 데이터 구조인 행렬을 n차원 데이터구조로 확장한 데이터 구조

# %%
# 배열 표현법
A1 <- array(data = 1:24, dim = c(4, 3, 2))
print(A1)
# Out:
# , , 1
#
#      [,1] [,2] [,3]
# [1,]    1    5    9
# [2,]    2    6   10
# [3,]    3    7   11
# [4,]    4    8   12
#
# , , 2
#
#      [,1] [,2] [,3]
# [1,]   13   17   21
# [2,]   14   18   22
# [3,]   15   19   23
# [4,]   16   20   24

# %% [markdown]
# # 5. 데이터프레임(DataFrame)
#
# - 데이터 유형에 관계없는 2차원 데이터구조
# - 엑셀 스프레드시트와 같은 형태

# %%
# 데이터프레임 표현법
D1 <- c(1, 2, 3)
D2 <- c("A", "B", "C")
D3 <- data.frame(D1, D2)

print(D3)
# Out:
#   D1 D2
# 1  1  A
# 2  2  B
# 3  3  C

# %% [markdown]
# # 6. 리스트(List)
#
# - 데이터 구조에 관계없이 데이터들을 모두 묶은 객체
# - (키, 값) 형태의 데이터를 담는 연관배열이다

# %%
L1 <- list(V1, F1, A1, D3)
print(L1)
# Out:
# [[1]]
# [1] 1 2 3
#
# [[2]]
# [1] 좋다     보통이다 싫다
# Levels: 좋다 < 보통이다 < 싫다
#
# [[3]]
# , , 1
#
#      [,1] [,2] [,3]
# [1,]    1    5    9
# [2,]    2    6   10
# [3,]    3    7   11
# [4,]    4    8   12
#
# , , 2
#
#      [,1] [,2] [,3]
# [1,]   13   17   21
# [2,]   14   18   22
# [3,]   15   19   23
# [4,]   16   20   24
#
#
# [[4]]
#   D1 D2
# 1  1  A
# 2  2  B
# 3  3  C

# %%
L2 <- list(x = 1:4, y = c("A", "B"))
print(L2)
# Out:
# $x
# [1] 1 2 3 4
#
# $y
# [1] "A" "B"

# %%
L2$y # 리스트에서 특정 데이터만 꺼내기
# Out:
# [1] "A" "B"

# %% [markdown]
# ![R데이터구조2.png](data:image/png;base64,...)
